# %% [markdown]
# Reference: https://nipunbatra.github.io/blog/2017/50-ggplot-python-1.html

# %% [markdown]
# ### Library

# %%
import pandas as pd

# %%
from plotnine import *

# %% [markdown]
# ### Color scheme - Color Blind
#
# Tableau’s "Color Blind" : http://tableaufriction.blogspot.com/2012/11/finally-you-can-use-tableau-data-colors.html

# %%
# These are the "Tableau Color Blind" colors as Hex.  
 color=['#006BA4','#FF800E','#ABABAB','#A2C8EC','#595959']

# %% [markdown]
# ### Getting the data

# %%
cars=pd.read_csv("cars-sample.csv")

# %%
ggplot(cars, aes('Weight', 'MPG', color='Manufacturer',size='Weight')) + geom_point(alpha=0.5) + scale_color_manual(values=color)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/plotnine/layer.py:449: UserWarning: geom_point : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (-9223372036565453515)>
